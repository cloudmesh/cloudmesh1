# %%
from pprint import pprint

# %% [markdown]
# Initialize cloudmesh

# %%
import cloudmesh

# %%
print cloudmesh.__version__
# Out:
# 0.5

# %% [markdown]
# Get the user name

# %%
user = cloudmesh.load().username()

# %%
print user
# Out:
# gvonlasz

# %% [markdown]
# Specify a host

# %%
host = "india.futuregrid.org"

# %% [markdown]
# Start an instance to indi to interact with it to conduct pbs calls

# %%
india = cloudmesh.PBS(user,host)

# %% [markdown]
# Get the Queue information in a dict

# %%
queue = india.qstat()

# %% [markdown]
# Print the dict

# %%
pprint (queue)
# Out:
# {u'774570.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/liux2102/testjob.e774570',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'774570.i136',
#                   u'Job_Name': u'testjob',
#                   u'Job_Owner': u'liux2102@i136',
#                   u'Join_Path': u'oe',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i136:/N/u/liux2102/testjob.o774570',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'21',
#                                      u'nodes': u'21:ppn=8',
#                                      u'walltime': u'04:00:00'},
#                   u'ctime': u'1378303592',
#                   u'etime': u'1379341859',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/liux2102',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379341859',
#                   u'qtime': u'1378303592',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'testjob.pbs',
#                   u'submit_host': u'i136'},
#  u'783952.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/inca/incaReporterManager/sub12114.stderr',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'783952.i136',
#                   u'Job_Name': u'sub12114.sub',
#                   u'Job_Owner': u'inca@i136',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'n',
#                   u'Output_Path': u'i136:/N/u/inca/incaReporterManager/sub12114.stdout',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'16',
#                                      u'nodes': u'16:ppn=8',
#                                      u'walltime': u'07:00:00'},
#                   u'Shell_Path_List': u'/bin/sh',
#                   u'ctime': u'1379392320',
#                   u'etime': u'1379392320',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/inca/incaReporterManager',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379392320',
#                   u'qtime': u'1379392320',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'/N/u/inca/incaReporterManager/sub12114.sub',
#                   u'submit_host': u'i136'},
#  u'784967.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/inca/incaReporterManager/sub30133.stderr',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'784967.i136',
#                   u'Job_Name': u'papi-inca',
#                   u'Job_Owner': u'inca@i136',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'n',
#                   u'Output_Path': u'i136:/N/u/inca/incaReporterManager/sub30133.stdout',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'1',
#                                      u'nodes': u'1',
#                                      u'walltime': u'00:10:00'},
#                   u'Shell_Path_List': u'/bin/sh',
#                   u'ctime': u'1379611441',
#                   u'etime': u'1379611441',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/inca/incaReporterManager',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379611441',
#                   u'qtime': u'1379611441',
#                   u'queue': u'bravo',
#                   u'server': u'i136',
#                   u'submit_args': u'/N/u/inca/incaReporterManager/sub30133.sub',
#                   u'submit_host': u'i136'},
#  u'785040.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/inca/incaReporterManager/sub9073.stderr',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'785040.i136',
#                   u'Job_Name': u'sub9073.sub',
#                   u'Job_Owner': u'inca@i136',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'n',
#                   u'Output_Path': u'i136:/N/u/inca/incaReporterManager/sub9073.stdout',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'1',
#                                      u'nodes': u'1:ppn=8',
#                                      u'walltime': u'00:10:00'},
#                   u'Shell_Path_List': u'/bin/sh',
#                   u'ctime': u'1379621401',
#                   u'etime': u'1379621401',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/inca/incaReporterManager',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379621401',
#                   u'qtime': u'1379621401',
#                   u'queue': u'bravo',
#                   u'server': u'i136',
#                   u'submit_args': u'/N/u/inca/incaReporterManager/sub9073.sub',
#                   u'submit_host': u'i136'},
#  u'788236.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/inca/incaReporterManager/sub12111.stderr',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'788236.i136',
#                   u'Job_Name': u'papi-inca',
#                   u'Job_Owner': u'inca@i136',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'n',
#                   u'Output_Path': u'i136:/N/u/inca/incaReporterManager/sub12111.stdout',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'1',
#                                      u'nodes': u'1',
#                                      u'walltime': u'00:10:00'},
#                   u'Shell_Path_List': u'/bin/sh',
#                   u'ctime': u'1379641680',
#                   u'etime': u'1379641680',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/inca/incaReporterManager',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379641680',
#                   u'qtime': u'1379641680',
#                   u'queue': u'bravo',
#                   u'server': u'i136',
#                   u'submit_args': u'/N/u/inca/incaReporterManager/sub12111.sub',
#                   u'submit_host': u'i136'},
#  u'788237.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/inca/incaReporterManager/sub12158.stderr',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'788237.i136',
#                   u'Job_Name': u'sub12158.sub',
#                   u'Job_Owner': u'inca@i136',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'n',
#                   u'Output_Path': u'i136:/N/u/inca/incaReporterManager/sub12158.stdout',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'1',
#                                      u'nodes': u'1:ppn=8',
#                                      u'walltime': u'00:10:00'},
#                   u'Shell_Path_List': u'/bin/sh',
#                   u'ctime': u'1379641681',
#                   u'etime': u'1379641681',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/inca/incaReporterManager',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379641681',
#                   u'qtime': u'1379641681',
#                   u'queue': u'bravo',
#                   u'server': u'i136',
#                   u'submit_args': u'/N/u/inca/incaReporterManager/sub12158.sub',
#                   u'submit_host': u'i136'},
#  u'804534.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/inca/incaReporterManager/sub8257.stderr',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'804534.i136',
#                   u'Job_Name': u'sub8257.sub',
#                   u'Job_Owner': u'inca@i136',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'n',
#                   u'Output_Path': u'i136:/N/u/inca/incaReporterManager/sub8257.stdout',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'1',
#                                      u'nodes': u'1:ppn=8',
#                                      u'walltime': u'00:10:00'},
#                   u'Shell_Path_List': u'/bin/sh',
#                   u'ctime': u'1379670481',
#                   u'etime': u'1379670481',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/inca/incaReporterManager',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379670481',
#                   u'qtime': u'1379670481',
#                   u'queue': u'bravo',
#                   u'server': u'i136',
#                   u'submit_args': u'/N/u/inca/incaReporterManager/sub8257.sub',
#                   u'submit_host': u'i136'},
#  u'809363.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/inca/incaReporterManager/sub4286.stderr',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'809363.i136',
#                   u'Job_Name': u'vampir-inca',
#                   u'Job_Owner': u'inca@i136',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'n',
#                   u'Output_Path': u'i136:/N/u/inca/incaReporterManager/sub4286.stdout',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'1',
#                                      u'nodes': u'1',
#                                      u'walltime': u'00:10:00'},
#                   u'Shell_Path_List': u'/bin/sh',
#                   u'ctime': u'1379678760',
#                   u'etime': u'1379678760',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/inca/incaReporterManager',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379678760',
#                   u'qtime': u'1379678760',
#                   u'queue': u'bravo',
#                   u'server': u'i136',
#                   u'submit_args': u'/N/u/inca/incaReporterManager/sub4286.sub',
#                   u'submit_host': u'i136'},
#  u'812685.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/zhangbj/qsub.sh.e812685',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'812685.i136',
#                   u'Job_Name': u'qsub.sh',
#                   u'Job_Owner': u'zhangbj@i136',
#                   u'Join_Path': u'oe',
#                   u'Keep_Files': u'o',
#                   u'Mail_Points': u'abe',
#                   u'Output_Path': u'i136:/N/u/zhangbj/qsub.sh.o812685',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'naccesspolicy': u'singletask',
#                                      u'ncpus': u'1',
#                                      u'nodect': u'5',
#                                      u'nodes': u'5',
#                                      u'walltime': u'24:00:00'},
#                   u'ctime': u'1379692019',
#                   u'etime': u'1379692019',
#                   u'fault_tolerant': u'False',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379692019',
#                   u'qtime': u'1379692019',
#                   u'queue': u'bravo',
#                   u'server': u'i136',
#                   u'submit_args': u'qsub.sh'},
#  u'812688.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i81:/N/u/pela3247/lipid-converter/gromos53a6_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'812688.i136',
#                   u'Job_Name': u'gromos53a6_128_popc',
#                   u'Job_Owner': u'pela3247@i81',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i81:/N/u/pela3247/lipid-converter/gromos53a6_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'ctime': u'1379704241',
#                   u'depend': u'beforeany:826185.i136@i136',
#                   u'etime': u'1379790684',
#                   u'exec_host': u'i91/7+i91/6+i91/5+i91/4+i91/3+i91/2+i91/1+i91/0+i93/7+i93/6+i93/5+i93/4+i93/3+i93/2+i93/1+i93/0',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos53a6_128_popc',
#                   u'job_state': u'R',
#                   u'mtime': u'1379790699',
#                   u'qtime': u'1379704241',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'43:17:01',
#                                       u'mem': u'650280kb',
#                                       u'vmem': u'3501496kb',
#                                       u'walltime': u'02:42:25'},
#                   u'server': u'i136',
#                   u'session_id': u'20554',
#                   u'start_count': u'1',
#                   u'start_time': u'1379790685',
#                   u'submit_args': u'-W depend=afterany:784996.i136 run_job.sh',
#                   u'submit_host': u'i81'},
#  u'812689.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i62:/N/u/pela3247/lipid-converter/gromos54a7_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'812689.i136',
#                   u'Job_Name': u'gromos54a7_128_popc',
#                   u'Job_Owner': u'pela3247@i62',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i62:/N/u/pela3247/lipid-converter/gromos54a7_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'ctime': u'1379704427',
#                   u'depend': u'beforeany:826234.i136@i136',
#                   u'etime': u'1379790840',
#                   u'exec_host': u'i83/7+i83/6+i83/5+i83/4+i83/3+i83/2+i83/1+i83/0+i90/7+i90/6+i90/5+i90/4+i90/3+i90/2+i90/1+i90/0',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos54a7_128_popc',
#                   u'job_state': u'R',
#                   u'mtime': u'1379790880',
#                   u'qtime': u'1379704427',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'42:40:28',
#                                       u'mem': u'653000kb',
#                                       u'vmem': u'3502068kb',
#                                       u'walltime': u'02:40:10'},
#                   u'server': u'i136',
#                   u'session_id': u'19172',
#                   u'start_count': u'1',
#                   u'start_time': u'1379790841',
#                   u'submit_args': u'-W depend=afterany:784998.i136 run_job.sh',
#                   u'submit_host': u'i62'},
#  u'812698.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i84:/N/u/pela3247/lipid-converter/gromos43a1S3_128_pope/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'812698.i136',
#                   u'Job_Name': u'gromos43a1S3_128_pope',
#                   u'Job_Owner': u'pela3247@i84',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i84:/N/u/pela3247/lipid-converter/gromos43a1S3_128_pope/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'ctime': u'1379709415',
#                   u'depend': u'beforeany:827742.i136@i136',
#                   u'etime': u'1379795827',
#                   u'exec_host': u'i84/7+i84/6+i84/5+i84/4+i84/3+i84/2+i84/1+i84/0+i85/7+i85/6+i85/5+i85/4+i85/3+i85/2+i85/1+i85/0',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos43a1S3_128_pope',
#                   u'job_state': u'R',
#                   u'mtime': u'1379795884',
#                   u'qtime': u'1379709415',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'20:32:56',
#                                       u'mem': u'670476kb',
#                                       u'vmem': u'3510076kb',
#                                       u'walltime': u'01:17:14'},
#                   u'server': u'i136',
#                   u'session_id': u'17965',
#                   u'start_count': u'1',
#                   u'start_time': u'1379795828',
#                   u'submit_args': u'-W depend=afterany:785118.i136 run_job.sh',
#                   u'submit_host': u'i84'},
#  u'812699.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i86:/N/u/pela3247/lipid-converter/gromos43a1S3_128_dmpc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'812699.i136',
#                   u'Job_Name': u'gromos43a1S3_128_dmpc',
#                   u'Job_Owner': u'pela3247@i86',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i86:/N/u/pela3247/lipid-converter/gromos43a1S3_128_dmpc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'ctime': u'1379709736',
#                   u'depend': u'beforeany:827837.i136@i136',
#                   u'etime': u'1379796139',
#                   u'exec_host': u'i81/7+i81/6+i81/5+i81/4+i81/3+i81/2+i81/1+i81/0+i82/7+i82/6+i82/5+i82/4+i82/3+i82/2+i82/1+i82/0',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos43a1S3_128_dmpc',
#                   u'job_state': u'R',
#                   u'mtime': u'1379796155',
#                   u'qtime': u'1379709736',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'19:06:11',
#                                       u'mem': u'662976kb',
#                                       u'vmem': u'3503740kb',
#                                       u'walltime': u'01:11:48'},
#                   u'server': u'i136',
#                   u'session_id': u'2325',
#                   u'start_count': u'1',
#                   u'start_time': u'1379796140',
#                   u'submit_args': u'-W depend=afterany:785120.i136 run_job.sh',
#                   u'submit_host': u'i86'},
#  u'812700.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/gromos43a1S3_128_dlpc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'812700.i136',
#                   u'Job_Name': u'gromos43a1S3_128_dlpc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/gromos43a1S3_128_dlpc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'ctime': u'1379709863',
#                   u'depend': u'beforeany:827876.i136@i136',
#                   u'etime': u'1379796267',
#                   u'exec_host': u'i62/7+i62/6+i62/5+i62/4+i62/3+i62/2+i62/1+i62/0+i63/7+i63/6+i63/5+i63/4+i63/3+i63/2+i63/1+i63/0',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos43a1S3_128_dlpc',
#                   u'job_state': u'R',
#                   u'mtime': u'1379796291',
#                   u'qtime': u'1379709863',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'18:37:56',
#                                       u'mem': u'660920kb',
#                                       u'vmem': u'3501152kb',
#                                       u'walltime': u'01:10:01'},
#                   u'server': u'i136',
#                   u'session_id': u'24487',
#                   u'start_count': u'1',
#                   u'start_time': u'1379796268',
#                   u'submit_args': u'-W depend=afterany:785139.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'812702.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i67:/N/u/pela3247/lipid-converter/opls_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'812702.i136',
#                   u'Job_Name': u'opls_128_popc',
#                   u'Job_Owner': u'pela3247@i67',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i67:/N/u/pela3247/lipid-converter/opls_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'ctime': u'1379711259',
#                   u'depend': u'beforeany:828319.i136@i136',
#                   u'etime': u'1379797703',
#                   u'exec_host': u'i86/7+i86/6+i86/5+i86/4+i86/3+i86/2+i86/1+i86/0+i87/7+i87/6+i87/5+i87/4+i87/3+i87/2+i87/1+i87/0',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/opls_128_popc',
#                   u'job_state': u'R',
#                   u'mtime': u'1379797733',
#                   u'qtime': u'1379711259',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'12:12:36',
#                                       u'mem': u'643916kb',
#                                       u'vmem': u'3480988kb',
#                                       u'walltime': u'00:45:52'},
#                   u'server': u'i136',
#                   u'session_id': u'29710',
#                   u'start_count': u'1',
#                   u'start_time': u'1379797706',
#                   u'submit_args': u'-W depend=afterany:785183.i136 run_job.sh',
#                   u'submit_host': u'i67'},
#  u'818482.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i136:/N/u/inca/incaReporterManager/sub22418.stderr',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'818482.i136',
#                   u'Job_Name': u'vampir-inca',
#                   u'Job_Owner': u'inca@i136',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'n',
#                   u'Output_Path': u'i136:/N/u/inca/incaReporterManager/sub22418.stdout',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'1',
#                                      u'nodes': u'1',
#                                      u'walltime': u'00:10:00'},
#                   u'Shell_Path_List': u'/bin/sh',
#                   u'ctime': u'1379765160',
#                   u'etime': u'1379765160',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/inca/incaReporterManager',
#                   u'job_state': u'Q',
#                   u'mtime': u'1379765160',
#                   u'qtime': u'1379765160',
#                   u'queue': u'bravo',
#                   u'server': u'i136',
#                   u'submit_args': u'/N/u/inca/incaReporterManager/sub22418.sub',
#                   u'submit_host': u'i136'},
#  u'826185.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i91:/N/u/pela3247/lipid-converter/gromos53a6_128_popc/run.eo',
#                   u'Hold_Types': u's',
#                   u'Job_Id': u'826185.i136',
#                   u'Job_Name': u'gromos53a6_128_popc',
#                   u'Job_Owner': u'pela3247@i91',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i91:/N/u/pela3247/lipid-converter/gromos53a6_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'ctime': u'1379790685',
#                   u'depend': u'afterany:812688.i136@i136',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos53a6_128_popc',
#                   u'job_state': u'H',
#                   u'mtime': u'1379790685',
#                   u'qtime': u'1379790685',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'-W depend=afterany:812688.i136 run_job.sh',
#                   u'submit_host': u'i91'},
#  u'826234.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i83:/N/u/pela3247/lipid-converter/gromos54a7_128_popc/run.eo',
#                   u'Hold_Types': u's',
#                   u'Job_Id': u'826234.i136',
#                   u'Job_Name': u'gromos54a7_128_popc',
#                   u'Job_Owner': u'pela3247@i83',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i83:/N/u/pela3247/lipid-converter/gromos54a7_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'ctime': u'1379790841',
#                   u'depend': u'afterany:812689.i136@i136',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos54a7_128_popc',
#                   u'job_state': u'H',
#                   u'mtime': u'1379790841',
#                   u'qtime': u'1379790841',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'-W depend=afterany:812689.i136 run_job.sh',
#                   u'submit_host': u'i83'},
#  u'827742.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i84:/N/u/pela3247/lipid-converter/gromos43a1S3_128_pope/run.eo',
#                   u'Hold_Types': u's',
#                   u'Job_Id': u'827742.i136',
#                   u'Job_Name': u'gromos43a1S3_128_pope',
#                   u'Job_Owner': u'pela3247@i84',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i84:/N/u/pela3247/lipid-converter/gromos43a1S3_128_pope/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'ctime': u'1379795828',
#                   u'depend': u'afterany:812698.i136@i136',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos43a1S3_128_pope',
#                   u'job_state': u'H',
#                   u'mtime': u'1379795828',
#                   u'qtime': u'1379795828',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'-W depend=afterany:812698.i136 run_job.sh',
#                   u'submit_host': u'i84'},
#  u'827837.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i81:/N/u/pela3247/lipid-converter/gromos43a1S3_128_dmpc/run.eo',
#                   u'Hold_Types': u's',
#                   u'Job_Id': u'827837.i136',
#                   u'Job_Name': u'gromos43a1S3_128_dmpc',
#                   u'Job_Owner': u'pela3247@i81',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i81:/N/u/pela3247/lipid-converter/gromos43a1S3_128_dmpc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'ctime': u'1379796140',
#                   u'depend': u'afterany:812699.i136@i136',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos43a1S3_128_dmpc',
#                   u'job_state': u'H',
#                   u'mtime': u'1379796140',
#                   u'qtime': u'1379796140',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'-W depend=afterany:812699.i136 run_job.sh',
#                   u'submit_host': u'i81'},
#  u'827876.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i62:/N/u/pela3247/lipid-converter/gromos43a1S3_128_dlpc/run.eo',
#                   u'Hold_Types': u's',
#                   u'Job_Id': u'827876.i136',
#                   u'Job_Name': u'gromos43a1S3_128_dlpc',
#                   u'Job_Owner': u'pela3247@i62',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i62:/N/u/pela3247/lipid-converter/gromos43a1S3_128_dlpc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'ctime': u'1379796268',
#                   u'depend': u'afterany:812700.i136@i136',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/gromos43a1S3_128_dlpc',
#                   u'job_state': u'H',
#                   u'mtime': u'1379796268',
#                   u'qtime': u'1379796268',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'-W depend=afterany:812700.i136 run_job.sh',
#                   u'submit_host': u'i62'},
#  u'828319.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i86:/N/u/pela3247/lipid-converter/opls_128_popc/run.eo',
#                   u'Hold_Types': u's',
#                   u'Job_Id': u'828319.i136',
#                   u'Job_Name': u'opls_128_popc',
#                   u'Job_Owner': u'pela3247@i86',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i86:/N/u/pela3247/lipid-converter/opls_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'ctime': u'1379797706',
#                   u'depend': u'afterany:812702.i136@i136',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/opls_128_popc',
#                   u'job_state': u'H',
#                   u'mtime': u'1379797706',
#                   u'qtime': u'1379797706',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'-W depend=afterany:812702.i136 run_job.sh',
#                   u'submit_host': u'i86'},
#  u'829092.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829092.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i67',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800198',
#                   u'ctime': u'1379800193',
#                   u'depend': u'beforeany:829093.i136@i136',
#                   u'etime': u'1379800194',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800198',
#                   u'qtime': u'1379800193',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:03'},
#                   u'server': u'i136',
#                   u'session_id': u'3859',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800195',
#                   u'submit_args': u'-W depend=afterany:829091.i136 run_job.sh',
#                   u'submit_host': u'i67'},
#  u'829093.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829093.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800201',
#                   u'ctime': u'1379800195',
#                   u'depend': u'beforeany:829094.i136@i136',
#                   u'etime': u'1379800198',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800201',
#                   u'qtime': u'1379800195',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:02'},
#                   u'server': u'i136',
#                   u'session_id': u'3949',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800199',
#                   u'submit_args': u'-W depend=afterany:829092.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829094.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829094.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800205',
#                   u'ctime': u'1379800199',
#                   u'depend': u'beforeany:829095.i136@i136',
#                   u'etime': u'1379800201',
#                   u'exec_host': u'i67/7+i67/6+i67/5+i67/4+i67/3+i67/2+i67/1+i67/0+i69/7+i69/6+i69/5+i69/4+i69/3+i69/2+i69/1+i69/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800205',
#                   u'qtime': u'1379800199',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:03'},
#                   u'server': u'i136',
#                   u'session_id': u'17846',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800202',
#                   u'submit_args': u'-W depend=afterany:829093.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829095.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829095.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i67',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800209',
#                   u'ctime': u'1379800202',
#                   u'depend': u'beforeany:829096.i136@i136',
#                   u'etime': u'1379800205',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800208',
#                   u'qtime': u'1379800202',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:03'},
#                   u'server': u'i136',
#                   u'session_id': u'4040',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800205',
#                   u'submit_args': u'-W depend=afterany:829094.i136 run_job.sh',
#                   u'submit_host': u'i67'},
#  u'829096.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829096.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800211',
#                   u'ctime': u'1379800206',
#                   u'depend': u'beforeany:829097.i136@i136',
#                   u'etime': u'1379800209',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800211',
#                   u'qtime': u'1379800206',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:02'},
#                   u'server': u'i136',
#                   u'session_id': u'4123',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800209',
#                   u'submit_args': u'-W depend=afterany:829095.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829097.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829097.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800213',
#                   u'ctime': u'1379800209',
#                   u'depend': u'beforeany:829098.i136@i136',
#                   u'etime': u'1379800211',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800213',
#                   u'qtime': u'1379800209',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'596kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:01'},
#                   u'server': u'i136',
#                   u'session_id': u'4212',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800212',
#                   u'submit_args': u'-W depend=afterany:829096.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829098.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829098.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800218',
#                   u'ctime': u'1379800212',
#                   u'depend': u'beforeany:829099.i136@i136',
#                   u'etime': u'1379800213',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800218',
#                   u'qtime': u'1379800212',
# ...
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:02'},
#                   u'server': u'i136',
#                   u'session_id': u'20843',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800469',
#                   u'submit_args': u'-W depend=afterany:829171.i136 run_job.sh',
#                   u'submit_host': u'i67'},
#  u'829173.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829173.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i67',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800475',
#                   u'ctime': u'1379800469',
#                   u'depend': u'beforeany:829174.i136@i136',
#                   u'etime': u'1379800471',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800475',
#                   u'qtime': u'1379800469',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:01',
#                                       u'mem': u'596kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:03'},
#                   u'server': u'i136',
#                   u'session_id': u'7394',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800472',
#                   u'submit_args': u'-W depend=afterany:829172.i136 run_job.sh',
#                   u'submit_host': u'i67'},
#  u'829174.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829174.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800479',
#                   u'ctime': u'1379800472',
#                   u'depend': u'beforeany:829175.i136@i136',
#                   u'etime': u'1379800475',
#                   u'exec_host': u'i67/7+i67/6+i67/5+i67/4+i67/3+i67/2+i67/1+i67/0+i69/7+i69/6+i69/5+i69/4+i69/3+i69/2+i69/1+i69/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800479',
#                   u'qtime': u'1379800472',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'596kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:03'},
#                   u'server': u'i136',
#                   u'session_id': u'20924',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800476',
#                   u'submit_args': u'-W depend=afterany:829173.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829175.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829175.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i67',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800482',
#                   u'ctime': u'1379800476',
#                   u'depend': u'beforeany:829176.i136@i136',
#                   u'etime': u'1379800479',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800482',
#                   u'qtime': u'1379800476',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:03'},
#                   u'server': u'i136',
#                   u'session_id': u'7475',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800479',
#                   u'submit_args': u'-W depend=afterany:829174.i136 run_job.sh',
#                   u'submit_host': u'i67'},
#  u'829176.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829176.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800485',
#                   u'ctime': u'1379800480',
#                   u'depend': u'beforeany:829177.i136@i136',
#                   u'etime': u'1379800482',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800485',
#                   u'qtime': u'1379800480',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:02'},
#                   u'server': u'i136',
#                   u'session_id': u'7556',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800483',
#                   u'submit_args': u'-W depend=afterany:829175.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829177.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829177.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800489',
#                   u'ctime': u'1379800483',
#                   u'depend': u'beforeany:829178.i136@i136',
#                   u'etime': u'1379800485',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800489',
#                   u'qtime': u'1379800483',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:04'},
#                   u'server': u'i136',
#                   u'session_id': u'7637',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800485',
#                   u'submit_args': u'-W depend=afterany:829176.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829178.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829178.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'comp_time': u'1379800493',
#                   u'ctime': u'1379800485',
#                   u'depend': u'beforeany:829179.i136@i136',
#                   u'etime': u'1379800489',
#                   u'exec_host': u'i88/7+i88/6+i88/5+i88/4+i88/3+i88/2+i88/1+i88/0+i92/7+i92/6+i92/5+i92/4+i92/3+i92/2+i92/1+i92/0',
#                   u'exit_status': u'255',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'C',
#                   u'mtime': u'1379800493',
#                   u'qtime': u'1379800485',
#                   u'queue': u'batch',
#                   u'resources_used': {u'cput': u'00:00:00',
#                                       u'mem': u'600kb',
#                                       u'vmem': u'9024kb',
#                                       u'walltime': u'00:00:03'},
#                   u'server': u'i136',
#                   u'session_id': u'7718',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800490',
#                   u'submit_args': u'-W depend=afterany:829177.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829179.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u'n',
#                   u'Job_Id': u'829179.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i88',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i88:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'Walltime': None,
#                   u'ctime': u'1379800490',
#                   u'depend': u'beforeany:829180.i136@i136',
#                   u'etime': u'1379800493',
#                   u'exec_host': u'i67/7+i67/6+i67/5+i67/4+i67/3+i67/2+i67/1+i67/0+i69/7+i69/6+i69/5+i69/4+i69/3+i69/2+i69/1+i69/0',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'R',
#                   u'mtime': u'1379800493',
#                   u'qtime': u'1379800490',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'start_count': u'1',
#                   u'start_time': u'1379800493',
#                   u'submit_args': u'-W depend=afterany:829178.i136 run_job.sh',
#                   u'submit_host': u'i88'},
#  u'829180.i136': {u'Checkpoint': u'u',
#                   u'Error_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.eo',
#                   u'Hold_Types': u's',
#                   u'Job_Id': u'829180.i136',
#                   u'Job_Name': u'charmm_128_popc',
#                   u'Job_Owner': u'pela3247@i67',
#                   u'Join_Path': u'n',
#                   u'Keep_Files': u'n',
#                   u'Mail_Points': u'a',
#                   u'Output_Path': u'i67:/N/u/pela3247/lipid-converter/charmm_128_popc/run.o',
#                   u'Priority': u'0',
#                   u'Rerunable': u'True',
#                   u'Resource_List': {u'ncpus': u'1',
#                                      u'nodect': u'2',
#                                      u'nodes': u'2:ppn=8',
#                                      u'walltime': u'23:59:58'},
#                   u'ctime': u'1379800493',
#                   u'depend': u'afterany:829179.i136@i136',
#                   u'fault_tolerant': u'False',
#                   u'init_work_dir': u'/N/u/pela3247/lipid-converter/charmm_128_popc',
#                   u'job_state': u'H',
#                   u'mtime': u'1379800493',
#                   u'qtime': u'1379800493',
#                   u'queue': u'batch',
#                   u'server': u'i136',
#                   u'submit_args': u'-W depend=afterany:829179.i136 run_job.sh',
#                   u'submit_host': u'i67'}}

# %% [markdown]
# Demonstrating what we can do with the dict

# %%
print "{0:>20} | {1:>1} | {2:<30}".format('Owner', 
                                   "S", 
                                   "Job")
print 70 * "-"    
for name in queue:
    job = queue[name]
    print "{0:>20} | {1:>1} | {2:<30}".format(job['Job_Owner'], 
                                   job["job_state"], 
                                   job["Job_Name"])
# Out:
#                Owner | S | Job
# ----------------------------------------------------------------------
#         pela3247@i81 | H | gromos43a1S3_128_dmpc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#            inca@i136 | Q | sub9073.sub
#         pela3247@i67 | C | charmm_128_popc
#        liux2102@i136 | Q | testjob
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i84 | R | gromos43a1S3_128_pope
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i62 | H | gromos43a1S3_128_dlpc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i83 | H | gromos54a7_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i81 | R | gromos53a6_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#            inca@i136 | Q | sub8257.sub
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i86 | H | opls_128_popc
#            inca@i136 | Q | sub12114.sub
#            inca@i136 | Q | vampir-inca
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i86 | R | gromos43a1S3_128_dmpc
#         pela3247@i67 | C | charmm_128_popc
#            inca@i136 | Q | papi-inca
#         zhangbj@i136 | Q | qsub.sh
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#            inca@i136 | Q | vampir-inca
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | R | opls_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#            inca@i136 | Q | papi-inca
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i62 | R | gromos54a7_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | H | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | R | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i91 | H | gromos53a6_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i67 | C | charmm_128_popc
#         pela3247@i88 | R | gromos43a1S3_128_dlpc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i88 | C | charmm_128_popc
#         pela3247@i84 | H | gromos43a1S3_128_pope
#            inca@i136 | Q | sub12158.sub
